# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14
# %matplotlib inline
pd.set_option('display.max_columns',50)

# %%
# open the chicago Marathon data
rdata = pd.read_csv('ChicagoMarathon_results.csv')
rdata.pop('Unnamed: 0')
rdata.head()
# Out:
#    Place Overall  Place Gender  Place Division                Name (CTZ)  \
# 0              1             1             1.0       » Kirui, Abel (KEN)
# 1              2             2             1.0   » Chumba, Dickson (KEN)
# 2              3             3             1.0  » Kipketer, Gideon (KEN)
# 3              4             4             2.0  » Lonyangata, Paul (KEN)
# 4              5             5             2.0    » Sambu, Stephen (KEN)
#
#   City, State  BIB Division   Age      HALF    Finish Gender start_time  \
# 0         NaN    3    30-34  34.0  01:06:51  02:11:23   Male   07:30:03
# 1         NaN    1    25-29  29.0  01:06:51  02:11:26   Male   07:30:03
# 2         NaN    7    20-24  23.0  01:06:51  02:12:20   Male   07:30:03
# 3         NaN    6    20-24  24.0  01:06:51  02:13:17   Male   07:30:03
# 4         NaN    8    25-29  28.0  01:06:51  02:13:35   Male   07:30:03
#
#    mph05  mph10  mph15  mph20  mphHalf  mph25  mph30  mph35  mph40  mphFinal  \
# ...

# %%
mph_data = ['mph05','mph10','mph15','mph20','mphHalf','mph25','mph30','mph35','mph40','mphFinal']
mk_data = ['mk05','mk10','mk15','mk20','mkHalf','mk25','mk30','mk35','mk40','mkFinal']

# %%
rundata = rdata.copy()
#rundata = rundata.drop('mph05')
rundata.head()
#for elem in mph_data:
#    rundata = rundata.pop(elem)
#for elem in mk_data:
#    rundata = rundata.pop(elem)
#rundata.head()
# Out:
#    Place Overall  Place Gender  Place Division                Name (CTZ)  \
# 0              1             1             1.0       » Kirui, Abel (KEN)
# 1              2             2             1.0   » Chumba, Dickson (KEN)
# 2              3             3             1.0  » Kipketer, Gideon (KEN)
# 3              4             4             2.0  » Lonyangata, Paul (KEN)
# 4              5             5             2.0    » Sambu, Stephen (KEN)
#
#   City, State  BIB Division   Age      HALF    Finish Gender start_time  \
# 0         NaN    3    30-34  34.0  01:06:51  02:11:23   Male   07:30:03
# 1         NaN    1    25-29  29.0  01:06:51  02:11:26   Male   07:30:03
# 2         NaN    7    20-24  23.0  01:06:51  02:12:20   Male   07:30:03
# 3         NaN    6    20-24  24.0  01:06:51  02:13:17   Male   07:30:03
# 4         NaN    8    25-29  28.0  01:06:51  02:13:35   Male   07:30:03
#
#    mph05  mph10  mph15  mph20  mphHalf  mph25  mph30  mph35  mph40  mphFinal  \
# ...

# %%
rundata.pop('mk10')
rundata.head()
# Out:
#    Place Overall  Place Gender  Place Division                Name (CTZ)  \
# 0              1             1             1.0       » Kirui, Abel (KEN)
# 1              2             2             1.0   » Chumba, Dickson (KEN)
# 2              3             3             1.0  » Kipketer, Gideon (KEN)
# 3              4             4             2.0  » Lonyangata, Paul (KEN)
# 4              5             5             2.0    » Sambu, Stephen (KEN)
#
#   City, State  BIB Division   Age      HALF    Finish Gender start_time  \
# 0         NaN    3    30-34  34.0  01:06:51  02:11:23   Male   07:30:03
# 1         NaN    1    25-29  29.0  01:06:51  02:11:26   Male   07:30:03
# 2         NaN    7    20-24  23.0  01:06:51  02:12:20   Male   07:30:03
# 3         NaN    6    20-24  24.0  01:06:51  02:13:17   Male   07:30:03
# 4         NaN    8    25-29  28.0  01:06:51  02:13:35   Male   07:30:03
#
#     t05k    t10k    t15k    t20k   tHalf    t25k    t30k    t35k    t40k  \
# ...

# %%
rundata.to_csv("MarathonResults2016.csv",sep=",")
